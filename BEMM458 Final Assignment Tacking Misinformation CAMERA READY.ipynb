# %% [markdown]
# ## BEMM458 Final Assignment

# %% [markdown]
# ## You are a data scientist working for the European Union. There is an increasing concern inn  relation to the spread and amplification of misinformation on social media.
#
# ## General management needs you to conduct an analysis of recent conversations posted on Twitter in relation to spain. You have to identify ongoing misinformation campaigns and profile those users contributing to the spread of misinformation.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
pd.set_option('display.max_rows', 120)

# %%
pd.set_option('display.float_format', '{:.0f}'.format)

# %%
spainEnglishAll=pd.read_csv('./data/BEMM458FinalAssignment.csv')

# %%
spainEnglishAll.columns
# Out:
# Index(['Unnamed: 0', 'tweeet.id', 'tweet.text', 'tweet.created_at',
#        'tweet.author_id', 'tweet.lang', 'public_metrics.retweet_count',
#        'public_metrics.reply_count', 'public_metrics.like_count'],
#       dtype='object')

# %%
spainEnglishAll

# %% [markdown]
# ## Question 1. Which twitter conversations have large levels of amplification ? (15 points)
# ### Tip: consider number of retweets, likes, etc as proxies to measure the spread of information on social media

# %% [markdown]
# spainEnglishAll.groupby(["tweeet.id","tweet.text"])[["public_metrics.retweet_count","public_metrics.like_count","public_metrics.reply_count"]].max()

# %%
# Displaying tweets based on retweet count (Aproach 1)

df1 = spainEnglishAll.sort_values(by="public_metrics.retweet_count",ascending= False).head(10)
df1
# Out:
#        Unnamed: 0            tweeet.id  \
# 23467       23467  1461162679809155076
# 23656       23656  1461157780664901633
# 8820         8820  1461371211343020033
# 39357       39357  1461649200882405377
# 45373       45373  1461537918900600843
# 41908       41908  1461613145219239944
# 23655       23655  1461157789397438464
# 45333       45333  1461539133520695297
# 45374       45374  1461537902106537991
# 44456       44456  1461565440879206401
#
#                                               tweet.text  \
# 23467  RT @NCTsmtown_127: #Johnny’s Photo Diary:Spain...
# 23656  RT @NCTsmtown_127: #Johnny’s Photo Diary:Spain...
# 8820   RT @NCTsmtown_127: #Johnny’s Photo Diary:Spain...
# 39357  RT @NCTsmtown_127: Spain here we goooooo\n\n#N...
# 45373  RT @NCTsmtown_127: #Johnny’s Photo Diary:Spain...
# 41908  RT @NCTsmtown_127: #Johnny’s Photo Diary:Spain...
# 23655  RT @NCTsmtown_127: #Johnny’s Photo Diary:Spain...
# 45333  RT @NCTsmtown_127: #Johnny’s Photo Diary:Spain...
# 45374  RT @NCTsmtown_127: #Johnny’s Photo Diary:Spain...
# 44456  RT @NCTsmtown_127: #Johnny 's Photo Diary:Spai...
#
#                 tweet.created_at     tweet.author_id tweet.lang  \
# 23467  2021-11-18 02:41:44+00:00 1290910527393210368         en
# 23656  2021-11-18 02:22:16+00:00 1101831422631804800         en
# 8820   2021-11-18 16:30:22+00:00          1168957082         en
# 39357  2021-11-19 10:55:00+00:00 1064006291087970432         en
# 45373  2021-11-19 03:32:48+00:00 1382234880465989632         en
# 41908  2021-11-19 08:31:43+00:00 1388490486181076992         en
# 23655  2021-11-18 02:22:18+00:00 1101831422631804800         en
# 45333  2021-11-19 03:37:38+00:00 1382234880465989632         en
# 45374  2021-11-19 03:32:44+00:00 1382234880465989632         en
# 44456  2021-11-19 05:22:10+00:00 1322715465198821376         en
#
#        public_metrics.retweet_count  public_metrics.reply_count  \
# 23467                         44845                           0
# 23656                         43945                           0
# 8820                          43945                           0
# 39357                         35930                           0
# 45373                         34538                           0
# 41908                         34538                           0
# 23655                         34537                           0
# 45333                         32878                           0
# 45374                         32632                           0
# 44456                         30490                           0
#
#        public_metrics.like_count
# 23467                          0
# 23656                          0
# 8820                           0
# 39357                          0
# 45373                          0
# 41908                          0
# 23655                          0
# 45333                          0
# 45374                          0
# 44456                          0

# %%
# As we can see in the graph we are displaying some tweets based on retweet count. 
# 1461162679809155076 this id contains maximum number of retweet i.e 44845
plt.figure(figsize=(16,8))
plt.bar(list('0123456789'), df1['public_metrics.retweet_count'] )
# Out:
# <BarContainer object of 10 artists>

# %%
# Displaying tweets based on likes count (Approach 2)
df2 = spainEnglishAll.sort_values(by="public_metrics.like_count",ascending= False).head(10)
df2
# Out:
#        Unnamed: 0            tweeet.id  \
# 2434         2434  1461450207657349131
# 32805       32805  1461735560435752961
# 27778       27778  1461806775594885122
# 37178       37178  1461679405755944968
# 11708       11708  1461338150610083843
# 19850       19850  1461236789134376960
# 34485       34485  1461715384516714501
# 15636       15636  1461295289608945670
# 314           314  1461479072219820034
# 44889       44889  1461555171746455555
#
#                                               tweet.text  \
# 2434   EURO 2008 top scorer: Villa ⚽️\nWorld Cup 2010...
# 32805  "What if Lionel Messi picked Spain over Argent...
# 27778  From Spain: Manchester United are ready to bid...
# 37178  I wanted to go to LFL next year but as many of...
# 11708  Madrid, Spain 🇪🇸                #NaturePhotogr...
# 19850  Xavi will begin to use a software that he used...
# 34485  🚨⚽️ | Fifa have released their new rankings\n\...
# 15636  In the last 20 years Spain has built 1,900 mil...
# 314    argentina, brasil and spain: last night in soh...
# 44889  Jennifer Lawrence covers the December 2021 iss...
#
#                 tweet.created_at     tweet.author_id tweet.lang  \
# 2434   2021-11-18 21:44:16+00:00            18091004         en
# 32805  2021-11-19 16:38:09+00:00 1443958261917511680         en
# 27778  2021-11-19 21:21:09+00:00          2430359540         en
# 37178  2021-11-19 12:55:01+00:00           375634909         en
# 11708  2021-11-18 14:19:00+00:00 1383404685189545984         en
# 19850  2021-11-18 07:36:13+00:00  885972982052597760         en
# 34485  2021-11-19 15:17:59+00:00 1412833835776086016         en
# 15636  2021-11-18 11:28:41+00:00          1662773784         en
# 314    2021-11-18 23:38:58+00:00 1321957954371809280         en
# 44889  2021-11-19 04:41:21+00:00 1339619325578240000         en
#
#        public_metrics.retweet_count  public_metrics.reply_count  \
# 2434                           1568                         740
# 32805                           895                         138
# 27778                           379                         512
# 37178                           116                          79
# 11708                           861                          61
# 19850                           178                          30
# 34485                            93                         215
# 15636                           658                          57
# 314                             142                          13
# 44889                           200                          17
#
#        public_metrics.like_count
# 2434                       15423
# 32805                      12216
# 27778                       6058
# 37178                       4632
# 11708                       4240
# 19850                       3651
# 34485                       3358
# 15636                       2362
# 314                         2167
# 44889                       2082

# %%
# As we can see in the graph we are displaying some tweets based on like. 
# 1461450207657349131 this id contains maximum number of likes in the dataset i.e 1568
plt.figure(figsize=(16,8))
plt.bar(list('0123456789'), df2['public_metrics.like_count'] )
# Out:
# <BarContainer object of 10 artists>

# %%
#spainEnglishAll["tweeet.id"][["public_metrics.retweet_count","public_metrics.like_count","public_metrics.reply_count"]].max()

# %%
#spainEnglishAll['public_metrics.retweet_count'].max()

# %% [markdown]
# ## Question 2. Analysis of highly amplified conversations (15 points)
#
# ### Please describe  5 highly amplified conversations which are trying to polarize or misinform.
#
# ## Tip: given a tweet.id it is possible to have a detailed look at twitter by appending this id to the url: https://twitter.com/anyuser/status/
#
#
# ### For instance given the tweet.id: 1461577564850319362 you can inspect its content by having a look at: https://twitter.com/anyuser/status/1461577564850319362

# %%
retweet_count = spainEnglishAll['public_metrics.retweet_count'].quantile()
like_count = spainEnglishAll['public_metrics.like_count'].quantile()

# %%
topamplifiedtweetdata = spainEnglishAll[(spainEnglishAll['public_metrics.retweet_count'] > retweet_count) & (spainEnglishAll['public_metrics.like_count'] > like_count)]

# %%
topamplifiedtweetdata.head(5)
# Out:
#      Unnamed: 0            tweeet.id  \
# 273         273  1461479688371646467
# 314         314  1461479072219820034
# 382         382  1461477730948685825
# 678         678  1461472642985254912
# 687         687  1461472487867404288
#
#                                             tweet.text  \
# 273  Its beyond my understanding rec cannabis is be...
# 314  argentina, brasil and spain: last night in soh...
# 382  Promotional banner of Justin Bieber’s #Justice...
# 678  GOP Senator @marcorubio of Florida blocked the...
# 687  ❗❗ ICYMI: Sen. Rubio joined @MariaBartiromo on...
#
#               tweet.created_at     tweet.author_id tweet.lang  \
# 273  2021-11-18 23:41:25+00:00            29311833         en
# 314  2021-11-18 23:38:58+00:00 1321957954371809280         en
# 382  2021-11-18 23:33:38+00:00 1329632834701692928         en
# 678  2021-11-18 23:13:25+00:00 1316523898989617152         en
# 687  2021-11-18 23:12:48+00:00           229966028         en
#
#      public_metrics.retweet_count  public_metrics.reply_count  \
# 273                            44                           2
# 314                           142                          13
# 382                            71                           4
# 678                            22                           1
# 687                            11                           5
#
#      public_metrics.like_count
# 273                        181
# 314                       2167
# 382                        314
# 678                         47
# 687                         32

# %% [markdown]
# ## Question 3. Compute the z-score of the column "public_metrics.retweet_count" (15 points)
# ## tip: refer to the definition of Z-score at" https://www.statisticshowto.com/probability-and-statistics/z-score/

# %% [markdown]
# ## Question 4. Filter conversations with a z-score larger than 10. (15 points)

# %% [markdown]
# ## Question 5. Find the top 5 amplifiers (15 points)
# ### we consider amplifiers those twitter users who are involved in highly amplified conversations

# %% [markdown]
# ## Question 6. Extract, from the text colum, information on who created the conversation in the first place (15 points)
# ### Tip: retweeted conversations start with the pattern RT@
# ### For illustration purposes, the text "RT @20splentyforus: France, like UK should set a national 30km/h or 20mph urban default limit." was originally created by @20splentyforus
# ### Tip2. consider applying a regex pattern to the DataFrame using apply method

# %% [markdown]
# ## Question 7. Please briefly reflect on how would you try to mitigate misinformation on social media (2 paragraphs maximum). (10 points)
